# %% [markdown]
# ### Cleaning Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# ...

# %%
print('''
VTAT- Vehicle time at arrival
CTAT- Customer time at arrival
''')
# Out:
# VTAT- Vehicle time at arrival
# CTAT- Customer time at arrival

# %%
df.dtypes
# Out:
# Date                                  object
# Time                                  object
# Booking ID                            object
# Booking Status                        object
# Customer ID                           object
# Vehicle Type                          object
# Pickup Location                       object
# Drop Location                         object
# Avg VTAT                             float64
# Avg CTAT                             float64
# Cancelled Rides by Customer          float64
# Reason for cancelling by Customer     object
# Cancelled Rides by Driver            float64
# Driver Cancellation Reason            object
# Incomplete Rides                     float64
# Incomplete Rides Reason               object
# Booking Value                        float64
# Ride Distance                        float64
# Driver Ratings                       float64
# Customer Rating                      float64
# Payment Method                        object
# ...

# %%
df.describe()
# Out:
#             Avg VTAT       Avg CTAT  Cancelled Rides by Customer  \
# count  139500.000000  102000.000000                      10500.0
# mean        8.456352      29.149636                          1.0
# std         3.773564       8.902577                          0.0
# min         2.000000      10.000000                          1.0
# 25%         5.300000      21.600000                          1.0
# 50%         8.300000      28.800000                          1.0
# 75%        11.300000      36.800000                          1.0
# max        20.000000      45.000000                          1.0
#
#        Cancelled Rides by Driver  Incomplete Rides  Booking Value  \
# count                    27000.0            9000.0  102000.000000
# mean                         1.0               1.0     508.295912
# std                          0.0               0.0     395.805774
# min                          1.0               1.0      50.000000
# ...

# %% [markdown]
# Changing date and time from object to datetime

# %%
#changing data types
df['Dates'] = pd.to_datetime(df['Date'])
df['xTime'] = pd.to_datetime(df['Time'])
# Out:
# C:\Users\Mahadevan\AppData\Local\Temp\ipykernel_32576\66524009.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['xTime'] = pd.to_datetime(df['Time'])

# %%
df.dtypes
# Out:
# Date                                         object
# Time                                         object
# Booking ID                                   object
# Booking Status                               object
# Customer ID                                  object
# Vehicle Type                                 object
# Pickup Location                              object
# Drop Location                                object
# Avg VTAT                                    float64
# Avg CTAT                                    float64
# Cancelled Rides by Customer                 float64
# Reason for cancelling by Customer            object
# Cancelled Rides by Driver                   float64
# Driver Cancellation Reason                   object
# Incomplete Rides                            float64
# Incomplete Rides Reason                      object
# Booking Value                               float64
# Ride Distance                               float64
# ...

# %%
df.drop(['Date'], axis=1)
# Out:
#             Time    Booking ID   Booking Status   Customer ID   Vehicle Type  \
# 0       12:29:38  "CNR5884300"  No Driver Found  "CID1982111"          eBike
# 1       18:01:39  "CNR1326809"       Incomplete  "CID4604802"       Go Sedan
# 2       08:56:10  "CNR8494506"        Completed  "CID9202816"           Auto
# 3       17:17:25  "CNR8906825"        Completed  "CID2610914"  Premier Sedan
# 4       22:08:00  "CNR1950162"        Completed  "CID9933542"           Bike
# ...          ...           ...              ...           ...            ...
# 149995  19:34:01  "CNR6500631"        Completed  "CID4337371"        Go Mini
# 149996  15:55:09  "CNR2468611"        Completed  "CID2325623"        Go Mini
# 149997  10:55:15  "CNR6358306"        Completed  "CID9925486"       Go Sedan
# 149998  07:53:34  "CNR3030099"        Completed  "CID9415487"           Auto
# 149999  15:38:03  "CNR3447390"        Completed  "CID4108667"  Premier Sedan
#
# ...

# %%
df.drop(['Time'], axis=1)
# Out:
#               Date    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  "CNR1950162"        Completed  "CID9933542"
# ...            ...           ...              ...           ...
# 149995  2024-11-11  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# 0               eBike             Palam Vihar            Jhilmil       NaN
# ...

# %% [markdown]
# Checking Null Values

# %%
df.isna()

# %%
df.rename(columns={'Dates':'Date', 'xTime':'Time'})
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df['Driver Cancellation Reason'].unique()
# Out:
# array([nan, 'Personal & Car related issues', 'Customer related issue',
#        'More than permitted people in there',
#        'The customer was coughing/sick'], dtype=object)

# %%
df['Reason for cancelling by Customer'].unique()
# Out:
# array([nan, 'Driver is not moving towards pickup location',
#        'Driver asked to cancel', 'AC is not working', 'Change of plans',
#        'Wrong Address'], dtype=object)

# %%
df['Incomplete Rides Reason'].unique()
# Out:
# array(['Na', 'Vehicle Breakdown', 'Other Issue', 'Customer Demand'],
#       dtype=object)

# %%
df['Incomplete Rides'].unique()
# Out:
# array([0., 1.])

# %%
#Replacing null values

df['Avg VTAT'] = df['Avg VTAT'].fillna(0)
df['Avg CTAT'] = df['Avg CTAT'].fillna(0)
df['Incomplete Rides'] = df['Incomplete Rides'].fillna(0)
df['Incomplete Rides Reason'] = df['Incomplete Rides Reason'].fillna("Na")
df['Payment Method'] = df['Incomplete Rides Reason'].fillna("No Payment Made")
df['Incomplete Rides'] = df['Incomplete Rides'].astype(bool)
df['Booking Value'] = df['Booking Value'].fillna(0)
df['Ride Distance'] = df['Ride Distance'].fillna(0)

# %%
df.to_csv("data_cleaned.csv")

# %%
df1 = pd.read_csv('data_cleaned.csv')
df1.head()
# Out:
#    Unnamed: 0        Date      Time    Booking ID   Booking Status  \
# 0           0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found
# 1           1  2024-11-29  18:01:39  "CNR1326809"       Incomplete
# 2           2  2024-08-23  08:56:10  "CNR8494506"        Completed
# 3           3  2024-10-21  17:17:25  "CNR8906825"        Completed
# 4           4  2024-09-16  22:08:00  "CNR1950162"        Completed
#
#     Customer ID   Vehicle Type      Pickup Location      Drop Location  \
# 0  "CID1982111"          eBike          Palam Vihar            Jhilmil
# 1  "CID4604802"       Go Sedan        Shastri Nagar  Gurgaon Sector 56
# 2  "CID9202816"           Auto              Khandsa      Malviya Nagar
# 3  "CID2610914"  Premier Sedan  Central Secretariat           Inderlok
# 4  "CID9933542"           Bike     Ghitorni Village        Khan Market
#
#    Avg VTAT  ...  Driver Cancellation Reason  Incomplete Rides  \
# 0       0.0  ...                         NaN             False
# ...
